# %%
import pandas as pd

# %%
db = pd.read_json('results/2022-08-23-13-41-32_city_notebooks.json', lines=True)

# %%
db
# Out:
#           id brandName                                          shortName  \
# 0    1774300    HUAWEI  Ноутбук Huawei MateBook D 15, 53013HST,  сереб...
# 1    1774287    HUAWEI     Ноутбук Huawei MateBook D 16, 53013JHP,  серый
# 2    1635667     HONOR   Ультрабук Honor MagicBook  X14, 5301AAPL,  серый
# 3    1402165        HP           Ноутбук HP 15s-eq1138ur, 22V11EA,  серый
# 4    1774316    HUAWEI     Ноутбук Huawei MateBook D 15, 53013GHA,  серый
# ..       ...       ...                                                ...
# 779  1788299        HP   Ноутбук HP ProBook 455 G8, 43A31EA,  серебристый
# 780  1795435    LENOVO  Ноутбук Lenovo IdeaPad L3 15ITL6, 82HL006SRE, ...
# 781  1782283    LENOVO     Ноутбук Lenovo V15 G2 ITL, 82KB0038RU,  черный
# 782  1718665        HP     Ноутбук HP 15s-fq2118ur, 61R80EA,  серебристый
# 783  1479867    LENOVO         Ноутбук Lenovo V15-IGL, 82C30026RU,  серый
#
#      categoryId categoryName  price  oldPrice  clubPrice
# ...
